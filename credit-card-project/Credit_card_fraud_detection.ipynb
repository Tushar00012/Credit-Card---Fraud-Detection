# %%
import pandas as pd

# %%
data = pd.read_csv('creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
data['Amount'] = sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data = data.drop(['Time'],axis=1)

# %%
data = data.drop_duplicates()

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
x = data.drop('Class',axis=1)
y = data['Class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import precision_score , recall_score, f1_score

# %%
# handle imbalace dataset to incresase score

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 275663 entries, 0 to 284806
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   V1      275663 non-null  float64
#  1   V2      275663 non-null  float64
#  2   V3      275663 non-null  float64
#  3   V4      275663 non-null  float64
#  4   V5      275663 non-null  float64
#  5   V6      275663 non-null  float64
#  6   V7      275663 non-null  float64
#  7   V8      275663 non-null  float64
#  8   V9      275663 non-null  float64
#  9   V10     275663 non-null  float64
#  10  V11     275663 non-null  float64
#  11  V12     275663 non-null  float64
#  12  V13     275663 non-null  float64
#  13  V14     275663 non-null  float64
#  14  V15     275663 non-null  float64
#  15  V16     275663 non-null  float64
#  16  V17     275663 non-null  float64
#  17  V18     275663 non-null  float64
#  18  V19     275663 non-null  float64
#  19  V20     275663 non-null  float64
# ...

# %%
data['Class']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 275663, dtype: int64

# %%
normal = data[data['Class']==0]

# %%
fraud=data[data['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
n_sample=normal.sample(n=473)

# %%
n_sample.shape
# Out:
# (473, 30)

# %%
new_data=pd.concat([n_sample,fraud],ignore_index=True)

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.723672  0.537306  2.425101 -1.895426 -0.521560 -0.719723  0.360803
# 1  2.058177  0.221433 -1.673264  0.417296  0.194388 -1.514729  0.307899
# 2  1.189599 -0.014983  0.781461  0.975239 -0.841284 -0.775336 -0.150687
# 3  1.160301 -0.023413  0.650953  0.861308 -0.642551 -0.626797 -0.046176
# 4  1.825495 -0.406246 -0.288100  1.390715 -0.723044 -0.480543 -0.465901
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.003182  0.990579 -1.903214  ...  0.047200  0.332641 -0.382426  0.420761
# 1 -0.469338  0.213406 -0.371910  ...  0.176168  0.692218  0.008277  0.052493
# 2 -0.108916  0.629673 -0.218018  ... -0.085506 -0.018768 -0.031979  0.766057
# 3 -0.124921  0.472557 -0.234815  ... -0.274939 -0.680372  0.044481  0.426383
# 4 -0.003067  1.043550  0.215519  ...  0.258073  0.717843  0.100202 -0.051939
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
x = new_data.drop('Class',axis=1)
y = new_data['Class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(x_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9526315789473684

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9894736842105263

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9215686274509803

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9543147208121827

# %%
from sklearn.tree import DecisionTreeClassifier as dtc
dt = dtc()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9263157894736842

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.94

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9215686274509803

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9306930693069307

# %%
from sklearn.ensemble import RandomForestClassifier as rfc

# %%
rf=rfc()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3=rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9421052631578948

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9789473684210527

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9441624365482234

# %%
final_data = pd.DataFrame({'Models':['LR','DT','RF'],
             "ACC":[accuracy_score(y_test,y_pred1)*100,
                    accuracy_score(y_test,y_pred2)*100,
                    accuracy_score(y_test,y_pred3)*100,
                   ]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  95.263158
# 1     DT  92.631579
# 2     RF  94.210526

# %%
sns.barplot(x='Models', y='ACC', data=final_data, palette=['#3498db', '#e74c3c', '#9b59b6'], hue='Models', dodge=False, legend=False)
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %%
# oversamlping

# %%
 x=data.drop('Class',axis=1)
 y=data['Class']

# %%
x.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
# !pip install imbalanced-learn
# Out:
# ...
#    ---------------------------------------- 0.0/258.3 kB ? eta -:--:--
#    --- ----------------------------------- 20.5/258.3 kB 330.3 kB/s eta 0:00:01
#    ---------------------- ----------------- 143.4/258.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 258.3/258.3 kB 2.0 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE

# %%
x_res , y_res = SMOTE().fit_resample(x,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_res,y_res,test_size=0.20,random_state=42)

# %%
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
ov_pred1=log.predict(x_test)

# %%
accuracy_score(y_test,ov_pred1)
# Out:
# 0.9453105127366547

# %%
precision_score(y_test,ov_pred1)
# Out:
# 0.9728545226373202

# %%
recall_score(y_test,ov_pred1)
# Out:
# 0.9161136665272803

# %%
f1_score(y_test,ov_pred1)
# Out:
# 0.9436319032191615

# %%
dt = dtc()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
ov_pred2=dt.predict(x_test)

# %%
accuracy_score(y_test,ov_pred2)
# Out:
# 0.9980831425560521

# %%
precision_score(y_test,ov_pred2)
# Out:
# 0.9972411790329606

# %%
recall_score(y_test,ov_pred2)
# Out:
# 0.998927331236478

# %%
f1_score(y_test,ov_pred2)
# Out:
# 0.9980835429931244

# %%
rf = rfc()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
ov_pred3=rf.predict(x_test)

# %%
accuracy_score(y_test,ov_pred3)
# Out:
# 0.9999273229405138

# %%
precision_score(y_test,ov_pred3)
# Out:
# 0.9998545745396376

# %%
recall_score(y_test,ov_pred3)
# Out:
# 1.0

# %%
f1_score(y_test,ov_pred3)
# Out:
# 0.9999272819822932

# %%
final_data = pd.DataFrame({'Models':['LR','DT','RF'],
             "ACC":[accuracy_score(y_test,ov_pred1)*100,
                    accuracy_score(y_test,ov_pred2)*100,
                    accuracy_score(y_test,ov_pred3)*100,
                   ]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  94.531051
# 1     DT  99.808314
# 2     RF  99.992732

# %%
sns.barplot(x='Models', y='ACC', data=final_data, palette=['#3498db', '#e74c3c', '#9b59b6'], hue='Models', dodge=False, legend=False)
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %%
rf1= rfc()

# %%
rf1.fit(x_res,y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rf1,"credit_card_fraud_detection")
# Out:
# ['credit_card_fraud_detection']

# %%
model = joblib.load("credit_card_fraud_detection")

# %%
pred = model.predict([[-2.312226542, 1.951992011, -1.609850732, 3.997905588, -0.522187865, -1.426545319, -2.537387306, 1.391657248, -2.770089277, -2.772272145, 3.202033207, -2.899907388, -0.595221881, -4.289253782, 0.38972412, -1.14074718, -2.830055675, -0.016822468, 0.416955705, 0.126910559, 0.517232371, -0.035049369, -0.465211076, 0.320198199, 0.044519167, 0.177839798, 0.261145003, -0.143275875,0
]])
# Out:
# C:\Users\Tushar Ranjan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
if pred ==0:
    print("Normal Transaction")
else:
    print("Fraud Transaction")
# Out:
# Fraud Transaction

# %%
# hence able to detect fraud transaction
